# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Loan.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14860\330572272.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Loan.csv")

# %%
df.head()
# Out:
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  ...  PostalCode    LoanSeqNum  LoanPurpose  \
# 0      1         O     89   27  ...       60400  F199Q1268030            P
# 1      1         O     73   17  ...       80200  F199Q1015092            N
# 2      1         O     75   16  ...       66000  F199Q1266886            N
# 3      1         O     76   14  ...       90700  F199Q1178167            N
# 4      1         O     78   18  ...        7600  F199Q1178517            N
#
# ...

# %%
df.shape
# Out:
# (291451, 28)

# %%
cols = df.columns
cols
# Out:
# Index(['CreditScore', 'FirstPaymentDate', 'FirstTimeHomebuyer', 'MaturityDate',
#        'MSA', 'MIP', 'Units', 'Occupancy', 'OCLTV', 'DTI', 'OrigUPB', 'LTV',
#        'OrigInterestRate', 'Channel', 'PPM', 'ProductType', 'PropertyState',
#        'PropertyType', 'PostalCode', 'LoanSeqNum', 'LoanPurpose',
#        'OrigLoanTerm', 'NumBorrowers', 'SellerName', 'ServicerName',
#        'EverDelinquent', 'MonthsDelinquent', 'MonthsInRepayment'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CreditScore               0
# FirstPaymentDate          0
# FirstTimeHomebuyer        0
# MaturityDate              0
# MSA                       0
# MIP                       0
# Units                     0
# Occupancy                 0
# OCLTV                     0
# DTI                       0
# OrigUPB                   0
# LTV                       0
# OrigInterestRate          0
# Channel                   0
# PPM                       0
# ProductType               0
# PropertyState             0
# PropertyType              0
# PostalCode                0
# LoanSeqNum                0
# LoanPurpose               0
# OrigLoanTerm              0
# NumBorrowers              0
# SellerName            24994
# ServicerName              0
# EverDelinquent            0
# MonthsDelinquent          0
# MonthsInRepayment         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291451 entries, 0 to 291450
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CreditScore         291451 non-null  int64
#  1   FirstPaymentDate    291451 non-null  int64
#  2   FirstTimeHomebuyer  291451 non-null  object
#  3   MaturityDate        291451 non-null  int64
#  4   MSA                 291451 non-null  object
#  5   MIP                 291451 non-null  int64
#  6   Units               291451 non-null  int64
#  7   Occupancy           291451 non-null  object
#  8   OCLTV               291451 non-null  int64
#  9   DTI                 291451 non-null  int64
#  10  OrigUPB             291451 non-null  int64
#  11  LTV                 291451 non-null  int64
#  12  OrigInterestRate    291451 non-null  float64
#  13  Channel             291451 non-null  object
#  14  PPM                 291451 non-null  object
# ...

# %%
df.describe()
# Out:
#          CreditScore  FirstPaymentDate   MaturityDate            MIP  \
# count  291451.000000     291451.000000  291451.000000  291451.000000
# mean      708.936991     199904.760553  202902.367043       9.216685
# std        68.408791         13.821228      16.090508      12.648273
# min         0.000000     199901.000000  202402.000000       0.000000
# 25%       675.000000     199903.000000  202902.000000       0.000000
# 50%       717.000000     199904.000000  202903.000000       0.000000
# 75%       753.000000     199905.000000  202904.000000      25.000000
# max       849.000000     201303.000000  204302.000000      55.000000
#
#                Units          OCLTV            DTI        OrigUPB  \
# count  291451.000000  291451.000000  291451.000000  291451.000000
# mean        1.026022      76.960529      30.033453  124940.387921
# std         0.202986      15.236154      13.203974   53657.440624
# min         0.000000       0.000000       0.000000    8000.000000
# ...

# %%
df["SellerName"].unique()
# Out:
# array(['FL', 'FT', 'GM', 'Ot', 'RE', 'NO', 'ST', 'CR', 'CH', 'FI', 'HO',
#        'PR', nan, 'PN', 'WA', 'BA', 'G ', 'OL', 'AC', 'CO', 'BI'],
#       dtype=object)

# %%
#check if any missing values
fig, ax = plt.subplots(figsize=(15, 5))
x = df.isna().sum().index
y = df.isna().sum()
ax.bar(x=x, height=y)
ax.set_xticklabels(x, rotation = 45)
plt.tight_layout();
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14860\4172896560.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation = 45)

# %%
#remove null values from SellerName coulumn with mode
df = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# CreditScore           0
# FirstPaymentDate      0
# FirstTimeHomebuyer    0
# MaturityDate          0
# MSA                   0
# MIP                   0
# Units                 0
# Occupancy             0
# OCLTV                 0
# DTI                   0
# OrigUPB               0
# LTV                   0
# OrigInterestRate      0
# Channel               0
# PPM                   0
# ProductType           0
# PropertyState         0
# PropertyType          0
# PostalCode            0
# LoanSeqNum            0
# LoanPurpose           0
# OrigLoanTerm          0
# NumBorrowers          0
# SellerName            0
# ServicerName          0
# EverDelinquent        0
# MonthsDelinquent      0
# MonthsInRepayment     0
# dtype: int64

# %%
df.hist(figsize=(30,30), xrot=-45)
# Out:
# array([[<AxesSubplot:title={'center':'CreditScore'}>,
#         <AxesSubplot:title={'center':'FirstPaymentDate'}>,
#         <AxesSubplot:title={'center':'MaturityDate'}>,
#         <AxesSubplot:title={'center':'MIP'}>],
#        [<AxesSubplot:title={'center':'Units'}>,
#         <AxesSubplot:title={'center':'OCLTV'}>,
#         <AxesSubplot:title={'center':'DTI'}>,
#         <AxesSubplot:title={'center':'OrigUPB'}>],
#        [<AxesSubplot:title={'center':'LTV'}>,
#         <AxesSubplot:title={'center':'OrigInterestRate'}>,
#         <AxesSubplot:title={'center':'OrigLoanTerm'}>,
#         <AxesSubplot:title={'center':'EverDelinquent'}>],
#        [<AxesSubplot:title={'center':'MonthsDelinquent'}>,
#         <AxesSubplot:title={'center':'MonthsInRepayment'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(7,5))
sns.countplot(y='SellerName', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='SellerName'>

# %%
plt.figure(figsize=(7,3))
sns.countplot(y='LoanPurpose', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='LoanPurpose'>

# %%
df.describe(include=['object'])
# Out:
#        FirstTimeHomebuyer     MSA Occupancy Channel     PPM ProductType  \
# count              266457  266457    266457  266457  266457      266457
# unique                  3     392         3       4       3           1
# top                     N   X             O       T       N       FRM
# freq               171929   36460    252566  158052  257512      266457
#
#        PropertyState PropertyType PostalCode    LoanSeqNum LoanPurpose  \
# count         266457       266457     266457        266457      266457
# unique            53            7       1762        266457           3
# top               CA           SF      94500  F199Q1268030           P
# freq           39179       224913       2444             1      111720
#
#        NumBorrowers SellerName          ServicerName
# count        266457     266457                266457
# unique            3         20                    20
# top               2         Ot  Other servicers
# ...

# %%
# ServicerName = The name of the entity that services the loan during the current reporting period.

# Occupancy = The classification describing the property occupancy status at the time the loan was originated.
#P = Primary Residence
#S = Second Home
#I = Investment Property
#9 = Not Available

# Channel = The origination channel used by the party that delivered the loan to the issuer
#R = Retail
#B = Broker
#C = Correspondent
#T = Third Party Origination - Not Specified
#9 = Not Available

# LoanPurpose = The classification describing the purpose of the loan.
#C = Refinance - Cash Out
#N = Refinance - No Cash Out
#R = Refinance - Not Specified
#P = Purchase
#9 = Not Available

# %%
df.head()
# Out:
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  ...  PostalCode    LoanSeqNum  LoanPurpose  \
# 0      1         O     89   27  ...       60400  F199Q1268030            P
# 1      1         O     73   17  ...       80200  F199Q1015092            N
# 2      1         O     75   16  ...       66000  F199Q1266886            N
# 3      1         O     76   14  ...       90700  F199Q1178167            N
# 4      1         O     78   18  ...        7600  F199Q1178517            N
#
# ...

# %%
df["FirstTimeHomebuyer"].unique()
# Out:
# array(['N', 'X', 'Y'], dtype=object)

# %%
df = df.replace('X',np.nan)
df = df.dropna(axis=0)

# %%
df["FirstTimeHomebuyer"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["PPM"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["MSA"].value_counts()
# Out:
# X        25232
# 31084     6258
# 16974     6101
# 47644     4960
# 12060     4726
#          ...
# 21940        3
# 49500        2
# 25020        1
# 10380        1
# 32420        1
# Name: MSA, Length: 392, dtype: int64

# %%
df["MSA"].unique()
# Out:
# array(['16974', '19740', '29940', '31084', '35644', 'X    ', '48620',
#        '12060', '12420', '13140', '13644', '15764', '16700', '16940',
#        '19124', '20500', '20764', '21340', '22380', '22744', '23060',
#        '24660', '24860', '25540', '26900', '27060', '27140', '27260',
#        '28420', '29404', '31340', '33124', '33340', '33460', '34820',
#        '35004', '35084', '35380', '37100', '38060', '38900', '39300',
#        '39340', '39820', '40060', '40140', '40900', '41180', '41620',
#        '41700', '41740', '41884', '42044', '42220', '42644', '46060',
#        '46700', '47644', '47894', '49180', '49420', '12580', '14484',
#        '14860', '19380', '19804', '26420', '29420', '29620', '36084',
#        '36540', '37764', '37860', '37964', '38940', '45300', '48424',
#        '19660', '11460', '12100', '12220', '12940', '13820', '14740',
#        '15540', '16740', '17140', '17460', '17780', '22220', '23104',
# ...

# %%
df["MSA"] = df["MSA"].replace('X    ',np.nan)
df["MSA"] = df["MSA"].dropna(axis=0)

# %%
sns.distplot(df['MSA'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSA', ylabel='Density'>

# %%
df["Channel"].value_counts()
# Out:
# T    112600
# R     79802
# C       233
# B       113
# Name: Channel, dtype: int64

# %%
plt.figure(figsize=(7,3))
sns.countplot(y='Channel', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Channel'>

# %%
df["NumBorrowers"].value_counts()
# Out:
# 2     123645
# 1      68932
# X        171
# Name: NumBorrowers, dtype: int64

# %%
df = df.replace("X ",np.NaN)

# %%
df = df.dropna(axis=0)

# %%
df["NumBorrowers"].value_counts()
# Out:
# 2    106821
# 1     60538
# Name: NumBorrowers, dtype: int64

# %%
plt.figure(figsize=(9,7))
sns.countplot(y="ServicerName", data=df)

# %%
plt.figure(figsize=(4,2))
sns.countplot(y="NumBorrowers", data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='NumBorrowers'>

# %%
sns.set(style='whitegrid')
ax=sns.boxplot(x=df.CreditScore)

# %%
plt.figure(figsize=(15,10))
corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True);

# %%
df.shape
# Out:
# (167359, 28)

# %%
df.describe()
# Out:
#          CreditScore  FirstPaymentDate   MaturityDate            MIP  \
# count  167359.000000     167359.000000  167359.000000  167359.000000
# mean      709.008885     199904.904284  202902.724700      10.312687
# std        68.699479         15.528535      13.312966      13.151722
# min         0.000000     199901.000000  202404.000000       0.000000
# 25%       675.000000     199903.000000  202902.000000       0.000000
# 50%       717.000000     199904.000000  202903.000000       0.000000
# 75%       753.000000     199905.000000  202904.000000      25.000000
# max       849.000000     201303.000000  204302.000000      55.000000
#
#                Units          OCLTV            DTI        OrigUPB  \
# count  167359.000000  167359.000000  167359.000000  167359.000000
# mean        1.018194      77.992949      31.744549  129755.220813
# std         0.169100      15.311800      11.333784   53001.327968
# min         0.000000       0.000000       0.000000   10000.000000
# ...

# %%
plt.figure(figsize=(15,15))
sns.pairplot(df,diag_kind='kde')

# %%
df.describe(include="int64")
# Out:
#          CreditScore  FirstPaymentDate   MaturityDate            MIP  \
# count  167359.000000     167359.000000  167359.000000  167359.000000
# mean      709.008885     199904.904284  202902.724700      10.312687
# std        68.699479         15.528535      13.312966      13.151722
# min         0.000000     199901.000000  202404.000000       0.000000
# 25%       675.000000     199903.000000  202902.000000       0.000000
# 50%       717.000000     199904.000000  202903.000000       0.000000
# 75%       753.000000     199905.000000  202904.000000      25.000000
# max       849.000000     201303.000000  204302.000000      55.000000
#
#                Units          OCLTV            DTI        OrigUPB  \
# count  167359.000000  167359.000000  167359.000000  167359.000000
# mean        1.018194      77.992949      31.744549  129755.220813
# std         0.169100      15.311800      11.333784   53001.327968
# min         0.000000       0.000000       0.000000   10000.000000
# ...

# %%
# Checking credit score
df["CreditScore"].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(3, 2)
# Setting height and width of subplots
fig.set_figheight(15)
fig.set_figwidth(30)
# Adding spacing between boxes
fig.tight_layout(h_pad=True, w_pad=True)
sns.boxplot(df["CreditScore"], ax=ax[0, 0])
sns.boxplot(df["MIP"], ax=ax[0, 1])
sns.boxplot(df["LTV"], ax=ax[1, 0])
sns.boxplot(df["OCLTV"], ax=ax[1, 1])
sns.boxplot(df["DTI"], ax=ax[2, 0])
sns.boxplot(df["MonthsInRepayment"], ax=ax[2, 1])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
